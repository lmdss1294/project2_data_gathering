# %% [markdown]
# <a href="https://colab.research.google.com/github/lmdss1294/project2_data_gathering/blob/main/2011_data/2011_data_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/lmdss1294/project2_data_gathering/main/2011_data/2011.csv")

# %%
df = df.sort_values(by = '날짜')

# %%
df = df.drop(labels = ['출발공항명','도착공항명','구분','출/도착구분'],axis =1)

# %%
df.reset_index(inplace = True,drop = True)

# %%
df.head()
# Out:
#          날짜     항공사      편명 출발공항코드 도착공항코드        계획시간        예상시간        출발시간  \
# 0  20110101   이스타항공   ZE230    CJU    GMP  오후 9:15:00  오후 9:15:00  오후 9:23:00
# 1  20110101   이스타항공   ZE222    CJU    GMP  오후 5:00:00  오후 5:00:00  오후 5:16:00
# 2  20110101  아시아나항공  OZ8972    CJU    GMP  오후 5:00:00  오후 5:00:00  오후 5:21:00
# 3  20110101    제주항공   7C804    CJU    CJJ  오후 5:00:00  오후 5:00:00  오후 5:27:00
# 4  20110101    대한항공  KE1246    CJU    GMP  오후 5:05:00  오후 5:05:00  오후 5:24:00
#
#    현황
# 0  출발
# 1  출발
# 2  출발
# 3  출발
# 4  출발

# %%
df.tail()
# Out:
#              날짜     항공사      편명 출발공항코드 도착공항코드         계획시간         예상시간  \
# 57868  20111231  아시아나항공  OZ8124    CJU    TAE  오후 12:10:00  오후 12:10:00
# 57869  20111231     진에어   LJ308    CJU    GMP  오후 12:35:00  오후 12:35:00
# 57870  20111231   이스타항공   ZE214    CJU    GMP  오후 12:40:00  오후 12:40:00
# 57871  20111231    대한항공  KE1222    CJU    GMP  오후 12:45:00  오후 12:45:00
# 57872  20111231   티웨이항공   TW724    CJU    GMP   오후 9:25:00   오후 9:25:00
#
#               출발시간  현황
# 57868  오후 12:31:00  출발
# 57869  오후 12:55:00  출발
# 57870   오후 1:05:00  출발
# 57871   오후 1:08:00  출발
# 57872   오후 9:35:00  출발

# %%
len(df['계획시간'].iloc[53067])
# Out:
# 11

# %%
import numpy as np

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57873 entries, 0 to 57872
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      57873 non-null  int64
#  1   항공사     57799 non-null  object
#  2   편명      57873 non-null  object
#  3   출발공항코드  57873 non-null  object
#  4   도착공항코드  57873 non-null  object
#  5   계획시간    57871 non-null  object
#  6   예상시간    56729 non-null  object
#  7   출발시간    56810 non-null  object
#  8   현황      57484 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 4.0+ MB

# %%
df[df['현황'].isnull()==True]
# Out:
#              날짜     항공사      편명 출발공항코드 도착공항코드         계획시간         예상시간  \
# 1029   20110108  아시아나항공  OZ8988    CJU    ICN   오후 6:40:00   오후 6:40:00
# 1810   20110114  아시아나항공  OZ8988    CJU    ICN   오후 6:40:00   오후 6:40:00
# 6415   20110217  아시아나항공  OZ8988    CJU    ICN   오후 6:40:00   오후 6:40:00
# 11608  20110325    대한항공   KE717    CJU    NRT   오후 6:20:00   오후 6:20:00
# 11948  20110327  중국동방항공   MU274    CJU    PEK  오후 10:55:00          NaN
# ...         ...     ...     ...    ...    ...          ...          ...
# 51194  20111118   이스타항공  ZE1391    CJU    CGQ   오후 2:10:00          NaN
# 51686  20111121   이스타항공  ZE1391    CJU    CGQ   오후 2:10:00          NaN
# 52286  20111125   이스타항공  ZE1391    CJU    CGQ   오후 2:10:00          NaN
# 52802  20111128   이스타항공  ZE1391    CJU    CGQ   오후 2:10:00          NaN
# 53652  20111204    제주항공  7C0062    CJU    ICN  오후 11:30:00  오후 11:30:00
#
#               출발시간   현황
# 1029    오후 6:53:00  NaN
# 1810    오후 6:52:00  NaN
# 6415    오후 6:45:00  NaN
# ...

# %%
for i in range(len(df['현황'])):
  if pd.isna(df['현황'].iloc[i]):
    if df['출발시간'].iloc[i] != None:
      df['현황'].iloc[i] = '출발'
    
    else:
      df['현황'].iloc[i] = '취소'


       
  else:
    continue
# Out:
# <ipython-input-74-109b3715cecb>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['현황'].iloc[i] = '출발'

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/lmdss1294/project2_data_gathering/main/2011_data/AIR_AMOS_182_HR_2011_2011_2018.csv",encoding = 'CP949')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57873 entries, 0 to 57872
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      57873 non-null  int64
#  1   항공사     57799 non-null  object
#  2   편명      57873 non-null  object
#  3   출발공항코드  57873 non-null  object
#  4   도착공항코드  57873 non-null  object
#  5   계획시간    57871 non-null  object
#  6   예상시간    56729 non-null  object
#  7   출발시간    56810 non-null  object
#  8   현황      57873 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 4.0+ MB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57873 entries, 0 to 57872
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      57873 non-null  int64
#  1   항공사     57799 non-null  object
#  2   편명      57873 non-null  object
#  3   출발공항코드  57873 non-null  object
#  4   도착공항코드  57873 non-null  object
#  5   계획시간    57871 non-null  object
#  6   예상시간    56729 non-null  object
#  7   출발시간    56810 non-null  object
#  8   현황      57873 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 4.0+ MB

# %%
df['계획시간'].dropna(inplace = True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57873 entries, 0 to 57872
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      57873 non-null  int64
#  1   항공사     57799 non-null  object
#  2   편명      57873 non-null  object
#  3   출발공항코드  57873 non-null  object
#  4   도착공항코드  57873 non-null  object
#  5   계획시간    57871 non-null  object
#  6   예상시간    56729 non-null  object
#  7   출발시간    56810 non-null  object
#  8   현황      57873 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 4.0+ MB

# %%
df2.head()
# Out:
#     지점                일시  풍향(deg)  풍속(KT)  순간풍속(KT)  시정(m)  일기현상(null)  \
# 0  182  2011-01-01 00:00      320      23      35.0   1700        85.0
# 1  182  2011-01-01 01:00      340      18      36.0   1000        86.0
# 2  182  2011-01-01 02:00      310      19      38.0   3500        85.0
# 3  182  2011-01-01 03:00      330      18       NaN   1000        86.0
# 4  182  2011-01-01 04:00      330      22      40.0   1000        86.0
#
#    1층 운량(1/8)  2층 운량(1/8)  3층 운량(1/8)  ...  4층 운형(null)  1층 운고(FT)  2층 운고(FT)  \
# 0         7.0         NaN         NaN  ...          NaN     2500.0        NaN
# 1         7.0         NaN         NaN  ...          NaN     2500.0        NaN
# 2         7.0         NaN         NaN  ...          NaN     2500.0        NaN
# 3         7.0         NaN         NaN  ...          NaN     2500.0        NaN
# 4         7.0         NaN         NaN  ...          NaN     2500.0        NaN
#
# ...

# %%
df2.tail()
# Out:
#        지점                일시  풍향(deg)  풍속(KT)  순간풍속(KT)  시정(m)  일기현상(null)  \
# 8755  182  2011-12-31 19:00      300       9       NaN  10000         NaN
# 8756  182  2011-12-31 20:00      310       7       NaN  10000         NaN
# 8757  182  2011-12-31 21:00      280       5       NaN  10000         NaN
# 8758  182  2011-12-31 22:00      210       6       NaN  10000         NaN
# 8759  182  2011-12-31 23:00      240       1       NaN  10000         NaN
#
#       1층 운량(1/8)  2층 운량(1/8)  3층 운량(1/8)  ...  4층 운형(null)  1층 운고(FT)  \
# 8755         7.0         NaN         NaN  ...          NaN     2500.0
# 8756         7.0         NaN         NaN  ...          NaN     3000.0
# 8757         7.0         NaN         NaN  ...          NaN     3000.0
# 8758         7.0         NaN         NaN  ...          NaN     3000.0
# 8759         7.0         NaN         NaN  ...          NaN     3000.0
#
#       2층 운고(FT)  3층 운고(FT)  4층 운고(FT)  기온(°C)  이슬점온도(°C)  해면기압(hPa)  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 24 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   지점           8760 non-null   int64
#  1   일시           8760 non-null   object
#  2   풍향(deg)      8760 non-null   int64
#  3   풍속(KT)       8760 non-null   int64
#  4   순간풍속(KT)     340 non-null    float64
#  5   시정(m)        8760 non-null   int64
#  6   일기현상(null)   5558 non-null   float64
#  7   1층 운량(1/8)   7968 non-null   float64
#  8   2층 운량(1/8)   4644 non-null   float64
#  9   3층 운량(1/8)   1615 non-null   float64
#  10  4층 운량(1/8)   2 non-null      float64
#  11  1층 운형(null)  7968 non-null   float64
#  12  2층 운형(null)  4644 non-null   float64
#  13  3층 운형(null)  1615 non-null   float64
#  14  4층 운형(null)  2 non-null      float64
#  15  1층 운고(FT)    7968 non-null   float64
#  16  2층 운고(FT)    4644 non-null   float64
#  17  3층 운고(FT)    1615 non-null   float64
# ...

# %%
df2 = df2.drop(labels = ['지점','2층 운량(1/8)','3층 운량(1/8)','4층 운량(1/8)','2층 운고(FT)','3층 운고(FT)','4층 운고(FT)'],axis =1)

# %%
df2 = df2.drop(labels = ['2층 운형(null)','3층 운형(null)','4층 운형(null)'],axis =1)

# %%
df2
# Out:
#                     일시  풍향(deg)  풍속(KT)  순간풍속(KT)  시정(m)  일기현상(null)  \
# 0     2011-01-01 00:00      320      23      35.0   1700        85.0
# 1     2011-01-01 01:00      340      18      36.0   1000        86.0
# 2     2011-01-01 02:00      310      19      38.0   3500        85.0
# 3     2011-01-01 03:00      330      18       NaN   1000        86.0
# 4     2011-01-01 04:00      330      22      40.0   1000        86.0
# ...                ...      ...     ...       ...    ...         ...
# 8755  2011-12-31 19:00      300       9       NaN  10000         NaN
# 8756  2011-12-31 20:00      310       7       NaN  10000         NaN
# 8757  2011-12-31 21:00      280       5       NaN  10000         NaN
# 8758  2011-12-31 22:00      210       6       NaN  10000         NaN
# 8759  2011-12-31 23:00      240       1       NaN  10000         NaN
#
#       1층 운량(1/8)  1층 운형(null)  1층 운고(FT)  기온(°C)  이슬점온도(°C)  해면기압(hPa)  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   일시           8760 non-null   object
#  1   풍향(deg)      8760 non-null   int64
#  2   풍속(KT)       8760 non-null   int64
#  3   순간풍속(KT)     340 non-null    float64
#  4   시정(m)        8760 non-null   int64
#  5   일기현상(null)   5558 non-null   float64
#  6   1층 운량(1/8)   7968 non-null   float64
#  7   1층 운형(null)  7968 non-null   float64
#  8   1층 운고(FT)    7968 non-null   float64
#  9   기온(°C)       8760 non-null   float64
#  10  이슬점온도(°C)    8760 non-null   float64
#  11  해면기압(hPa)    8760 non-null   float64
#  12  현지기압(hPa)    8760 non-null   float64
#  13  강수량(mm)      1209 non-null   float64
# dtypes: float64(10), int64(3), object(1)
# memory usage: 958.2+ KB

# %%
df2['순간풍속(KT)'].fillna(df2['풍속(KT)'], inplace=True)
df2['강수량(mm)'].fillna(0, inplace=True)

# %%
df
# Out:
#              날짜     항공사      편명 출발공항코드 도착공항코드         계획시간         예상시간  \
# 0      20110101   이스타항공   ZE230    CJU    GMP   오후 9:15:00   오후 9:15:00
# 1      20110101   이스타항공   ZE222    CJU    GMP   오후 5:00:00   오후 5:00:00
# 2      20110101  아시아나항공  OZ8972    CJU    GMP   오후 5:00:00   오후 5:00:00
# 3      20110101    제주항공   7C804    CJU    CJJ   오후 5:00:00   오후 5:00:00
# 4      20110101    대한항공  KE1246    CJU    GMP   오후 5:05:00   오후 5:05:00
# ...         ...     ...     ...    ...    ...          ...          ...
# 57868  20111231  아시아나항공  OZ8124    CJU    TAE  오후 12:10:00  오후 12:10:00
# 57869  20111231     진에어   LJ308    CJU    GMP  오후 12:35:00  오후 12:35:00
# 57870  20111231   이스타항공   ZE214    CJU    GMP  오후 12:40:00  오후 12:40:00
# 57871  20111231    대한항공  KE1222    CJU    GMP  오후 12:45:00  오후 12:45:00
# 57872  20111231   티웨이항공   TW724    CJU    GMP   오후 9:25:00   오후 9:25:00
#
#               출발시간  현황
# 0       오후 9:23:00  출발
# 1       오후 5:16:00  출발
# 2       오후 5:21:00  출발
# ...

# %%
df2
# Out:
#                     일시  풍향(deg)  풍속(KT)  순간풍속(KT)  시정(m)  일기현상(null)  \
# 0     2011-01-01 00:00      320      23      35.0   1700        85.0
# 1     2011-01-01 01:00      340      18      36.0   1000        86.0
# 2     2011-01-01 02:00      310      19      38.0   3500        85.0
# 3     2011-01-01 03:00      330      18      18.0   1000        86.0
# 4     2011-01-01 04:00      330      22      40.0   1000        86.0
# ...                ...      ...     ...       ...    ...         ...
# 8755  2011-12-31 19:00      300       9       9.0  10000         NaN
# 8756  2011-12-31 20:00      310       7       7.0  10000         NaN
# 8757  2011-12-31 21:00      280       5       5.0  10000         NaN
# 8758  2011-12-31 22:00      210       6       6.0  10000         NaN
# 8759  2011-12-31 23:00      240       1       1.0  10000         NaN
#
#       1층 운량(1/8)  1층 운형(null)  1층 운고(FT)  기온(°C)  이슬점온도(°C)  해면기압(hPa)  \
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   일시           8760 non-null   object
#  1   풍향(deg)      8760 non-null   int64
#  2   풍속(KT)       8760 non-null   int64
#  3   순간풍속(KT)     8760 non-null   float64
#  4   시정(m)        8760 non-null   int64
#  5   일기현상(null)   5558 non-null   float64
#  6   1층 운량(1/8)   7968 non-null   float64
#  7   1층 운형(null)  7968 non-null   float64
#  8   1층 운고(FT)    7968 non-null   float64
#  9   기온(°C)       8760 non-null   float64
#  10  이슬점온도(°C)    8760 non-null   float64
#  11  해면기압(hPa)    8760 non-null   float64
#  12  현지기압(hPa)    8760 non-null   float64
#  13  강수량(mm)      8760 non-null   float64
# dtypes: float64(10), int64(3), object(1)
# memory usage: 958.2+ KB

# %%
df2 = df2.fillna(0)

# %%
df2 = df2.drop(labels = '일기현상(null)',axis =1)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8760 entries, 0 to 8759
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   일시           8760 non-null   datetime64[ns]
#  1   풍향(deg)      8760 non-null   int64
#  2   풍속(KT)       8760 non-null   int64
#  3   순간풍속(KT)     8760 non-null   float64
#  4   시정(m)        8760 non-null   int64
#  5   일기현상(null)   5558 non-null   float64
#  6   1층 운량(1/8)   7968 non-null   float64
#  7   1층 운형(null)  7968 non-null   float64
#  8   1층 운고(FT)    7968 non-null   float64
#  9   기온(°C)       8760 non-null   float64
#  10  이슬점온도(°C)    8760 non-null   float64
#  11  해면기압(hPa)    8760 non-null   float64
#  12  현지기압(hPa)    8760 non-null   float64
#  13  강수량(mm)      8760 non-null   float64
# dtypes: datetime64[ns](1), float64(10), int64(3)
# memory usage: 958.2 KB

# %%
import re

# '%I:%M:%S' 형식에 맞지 않는 데이터 찾기
pattern = re.compile(r'\b\d{1,2}:\d{1,2}\b')
invalid_data = df['계획시간'].astype(str).apply(lambda x: bool(pattern.search(x)))
invalid_df = df[invalid_data]

# '%I:%M:%S' 형식에 맞지 않는 데이터 출력
print(invalid_df)
# Out:
#              날짜     항공사      편명 출발공항코드 도착공항코드         계획시간         예상시간  \
# 0      20110101   이스타항공   ZE230    CJU    GMP   오후 9:15:00   오후 9:15:00
# 1      20110101   이스타항공   ZE222    CJU    GMP   오후 5:00:00   오후 5:00:00
# 2      20110101  아시아나항공  OZ8972    CJU    GMP   오후 5:00:00   오후 5:00:00
# 3      20110101    제주항공   7C804    CJU    CJJ   오후 5:00:00   오후 5:00:00
# 4      20110101    대한항공  KE1246    CJU    GMP   오후 5:05:00   오후 5:05:00
# ...         ...     ...     ...    ...    ...          ...          ...
# 57868  20111231  아시아나항공  OZ8124    CJU    TAE  오후 12:10:00  오후 12:10:00
# 57869  20111231     진에어   LJ308    CJU    GMP  오후 12:35:00  오후 12:35:00
# 57870  20111231   이스타항공   ZE214    CJU    GMP  오후 12:40:00  오후 12:40:00
# 57871  20111231    대한항공  KE1222    CJU    GMP  오후 12:45:00  오후 12:45:00
# 57872  20111231   티웨이항공   TW724    CJU    GMP   오후 9:25:00   오후 9:25:00
#
#               출발시간  현황
# 0       오후 9:23:00  출발
# 1       오후 5:16:00  출발
# 2       오후 5:21:00  출발
# ...

# %%
df
# Out:
#              날짜     항공사      편명 출발공항코드 도착공항코드         계획시간         예상시간  \
# 0      20110101   이스타항공   ZE230    CJU    GMP   오후 9:15:00   오후 9:15:00
# 1      20110101   이스타항공   ZE222    CJU    GMP   오후 5:00:00   오후 5:00:00
# 2      20110101  아시아나항공  OZ8972    CJU    GMP   오후 5:00:00   오후 5:00:00
# 3      20110101    제주항공   7C804    CJU    CJJ   오후 5:00:00   오후 5:00:00
# 4      20110101    대한항공  KE1246    CJU    GMP   오후 5:05:00   오후 5:05:00
# ...         ...     ...     ...    ...    ...          ...          ...
# 57868  20111231  아시아나항공  OZ8124    CJU    TAE  오후 12:10:00  오후 12:10:00
# 57869  20111231     진에어   LJ308    CJU    GMP  오후 12:35:00  오후 12:35:00
# 57870  20111231   이스타항공   ZE214    CJU    GMP  오후 12:40:00  오후 12:40:00
# 57871  20111231    대한항공  KE1222    CJU    GMP  오후 12:45:00  오후 12:45:00
# 57872  20111231   티웨이항공   TW724    CJU    GMP   오후 9:25:00   오후 9:25:00
#
#               출발시간  현황
# 0       오후 9:23:00  출발
# 1       오후 5:16:00  출발
# 2       오후 5:21:00  출발
# ...

# %%
df['계획시간']
# Out:
# 0         오후 9:15:00
# 1         오후 5:00:00
# 2         오후 5:00:00
# 3         오후 5:00:00
# 4         오후 5:05:00
#             ...
# 57868    오후 12:10:00
# 57869    오후 12:35:00
# 57870    오후 12:40:00
# 57871    오후 12:45:00
# 57872     오후 9:25:00
# Name: 계획시간, Length: 57873, dtype: object

# %%
df['계획시간']=df['계획시간'].dropna(inplace = True)

# %%
df
# Out:
#              날짜     항공사      편명 출발공항코드 도착공항코드  계획시간         예상시간         출발시간  \
# 0      20110101   이스타항공   ZE230    CJU    GMP  None   오후 9:15:00   오후 9:23:00
# 1      20110101   이스타항공   ZE222    CJU    GMP  None   오후 5:00:00   오후 5:16:00
# 2      20110101  아시아나항공  OZ8972    CJU    GMP  None   오후 5:00:00   오후 5:21:00
# 3      20110101    제주항공   7C804    CJU    CJJ  None   오후 5:00:00   오후 5:27:00
# 4      20110101    대한항공  KE1246    CJU    GMP  None   오후 5:05:00   오후 5:24:00
# ...         ...     ...     ...    ...    ...   ...          ...          ...
# 57868  20111231  아시아나항공  OZ8124    CJU    TAE  None  오후 12:10:00  오후 12:31:00
# 57869  20111231     진에어   LJ308    CJU    GMP  None  오후 12:35:00  오후 12:55:00
# 57870  20111231   이스타항공   ZE214    CJU    GMP  None  오후 12:40:00   오후 1:05:00
# 57871  20111231    대한항공  KE1222    CJU    GMP  None  오후 12:45:00   오후 1:08:00
# 57872  20111231   티웨이항공   TW724    CJU    GMP  None   오후 9:25:00   오후 9:35:00
#
#        현황
# 0      출발
# ...

# %%
import datetime

result = []

a = df['날짜']
b = df['계획시간']

if len(a) == len(b):
    for i in range(len(a)):

        a_dt = datetime.datetime.strptime(str(a.iloc[i]), '%Y%m%d')

        if type(b.iloc[i]) == float:
          print(b.iloc[i])
# Out:
# nan
# nan

# %%
df.dropna(subset=['계획시간'], inplace=True)

# %%
df
# Out:
#              날짜     항공사      편명 출발공항코드 도착공항코드         계획시간         예상시간  \
# 0      20110101   이스타항공   ZE230    CJU    GMP   오후 9:15:00   오후 9:15:00
# 1      20110101   이스타항공   ZE222    CJU    GMP   오후 5:00:00   오후 5:00:00
# 2      20110101  아시아나항공  OZ8972    CJU    GMP   오후 5:00:00   오후 5:00:00
# 3      20110101    제주항공   7C804    CJU    CJJ   오후 5:00:00   오후 5:00:00
# 4      20110101    대한항공  KE1246    CJU    GMP   오후 5:05:00   오후 5:05:00
# ...         ...     ...     ...    ...    ...          ...          ...
# 57868  20111231  아시아나항공  OZ8124    CJU    TAE  오후 12:10:00  오후 12:10:00
# 57869  20111231     진에어   LJ308    CJU    GMP  오후 12:35:00  오후 12:35:00
# 57870  20111231   이스타항공   ZE214    CJU    GMP  오후 12:40:00  오후 12:40:00
# 57871  20111231    대한항공  KE1222    CJU    GMP  오후 12:45:00  오후 12:45:00
# 57872  20111231   티웨이항공   TW724    CJU    GMP   오후 9:25:00   오후 9:25:00
#
#               출발시간  현황
# 0       오후 9:23:00  출발
# 1       오후 5:16:00  출발
# 2       오후 5:21:00  출발
# ...

# %%
import datetime

result = []

a = df['날짜']
b = df['계획시간'].fillna('0000-00-00 00:00:00')

if len(a) == len(b):
    for i in range(len(a)):

        a_dt = datetime.datetime.strptime(str(a.iloc[i]), '%Y%m%d')

        b_time = b.iloc[i].split(' ')[-1]
        b_str = ' '.join(b.iloc[i].split(' ')[:-1])

        if b_time != '00:00:00':
            b_dt = datetime.datetime.strptime(b_time, '%I:%M:%S')

            if '오후' in b_str:
                b_dt += datetime.timedelta(hours=12)
        else:
            b_dt = None

        result.append(f'{a_dt.date()} {b_dt.time() if b_dt else "00:00:00"}')

df['일시'] = result

# %%
#선형 보간법을 사용하여 예측

#물리적으로 기상상황이 시간 단위로 급변하지 않기 때문에 선형 보간 법으로 처리하여도 괜찮음.

# %%
df
# Out:
#              날짜     항공사      편명 출발공항코드 도착공항코드         계획시간         예상시간  \
# 0      20110101   이스타항공   ZE230    CJU    GMP   오후 9:15:00   오후 9:15:00
# 1      20110101   이스타항공   ZE222    CJU    GMP   오후 5:00:00   오후 5:00:00
# 2      20110101  아시아나항공  OZ8972    CJU    GMP   오후 5:00:00   오후 5:00:00
# 3      20110101    제주항공   7C804    CJU    CJJ   오후 5:00:00   오후 5:00:00
# 4      20110101    대한항공  KE1246    CJU    GMP   오후 5:05:00   오후 5:05:00
# ...         ...     ...     ...    ...    ...          ...          ...
# 57868  20111231  아시아나항공  OZ8124    CJU    TAE  오후 12:10:00  오후 12:10:00
# 57869  20111231     진에어   LJ308    CJU    GMP  오후 12:35:00  오후 12:35:00
# 57870  20111231   이스타항공   ZE214    CJU    GMP  오후 12:40:00  오후 12:40:00
# 57871  20111231    대한항공  KE1222    CJU    GMP  오후 12:45:00  오후 12:45:00
# 57872  20111231   티웨이항공   TW724    CJU    GMP   오후 9:25:00   오후 9:25:00
#
#               출발시간  현황                   일시
# 0       오후 9:23:00  출발  2011-01-01 21:15:00
# ...

# %%
df['일시'] = pd.to_datetime(df['일시'])
df2['일시'] = pd.to_datetime(df2['일시'])

# %%
# merge 함수를 사용하여 두 데이터프레임을 조인합니다.
df_merged = pd.merge(df, df2, on='일시', how='left')

# %%
import numpy as np
from scipy import interpolate

# %%
# merge 함수를 사용하여 두 데이터프레임을 조인합니다.
df_merged = pd.merge(df, df2, on='일시', how='left')

# 보간할 열만 선택합니다.
cols_to_interpolate = ['풍향(deg)', '풍속(KT)', '순간풍속(KT)', '시정(m)', '1층 운량(1/8)','1층 운고(FT)', '1층 운형(null)','기온(°C)', '이슬점온도(°C)', '해면기압(hPa)', '현지기압(hPa)', '강수량(mm)']

# 선형 보간을 사용하여 일치하지 않는 데이터를 추정합니다.
for col in cols_to_interpolate:
    # 보간 함수를 생성합니다.
    f = interpolate.interp1d(df2['일시'].values.astype(np.int64), df2[col], kind='linear', fill_value='extrapolate')
    # df1에서 일치하지 않는 데이터를 추출합니다.
    missing_data = df_merged[df_merged[col].isnull()]
    # 일치하지 않는 데이터의 값을 보간 함수로 추정합니다.
    df_merged.loc[missing_data.index, col] = f(missing_data['일시'].values.astype(np.int64))

# %%
df_merged
# Out:
#              날짜     항공사      편명 출발공항코드 도착공항코드         계획시간         예상시간  \
# 0      20110101   이스타항공   ZE230    CJU    GMP   오후 9:15:00   오후 9:15:00
# 1      20110101   이스타항공   ZE222    CJU    GMP   오후 5:00:00   오후 5:00:00
# 2      20110101  아시아나항공  OZ8972    CJU    GMP   오후 5:00:00   오후 5:00:00
# 3      20110101    제주항공   7C804    CJU    CJJ   오후 5:00:00   오후 5:00:00
# 4      20110101    대한항공  KE1246    CJU    GMP   오후 5:05:00   오후 5:05:00
# ...         ...     ...     ...    ...    ...          ...          ...
# 57866  20111231  아시아나항공  OZ8124    CJU    TAE  오후 12:10:00  오후 12:10:00
# 57867  20111231     진에어   LJ308    CJU    GMP  오후 12:35:00  오후 12:35:00
# 57868  20111231   이스타항공   ZE214    CJU    GMP  오후 12:40:00  오후 12:40:00
# 57869  20111231    대한항공  KE1222    CJU    GMP  오후 12:45:00  오후 12:45:00
# 57870  20111231   티웨이항공   TW724    CJU    GMP   오후 9:25:00   오후 9:25:00
#
#               출발시간  현황                  일시  ...    시정(m)  일기현상(null)  \
# ...

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57871 entries, 0 to 57870
# Data columns (total 23 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   날짜           57871 non-null  int64
#  1   항공사          57797 non-null  object
#  2   편명           57871 non-null  object
#  3   출발공항코드       57871 non-null  object
#  4   도착공항코드       57871 non-null  object
#  5   계획시간         57871 non-null  object
#  6   예상시간         56727 non-null  object
#  7   출발시간         56808 non-null  object
#  8   현황           57871 non-null  object
#  9   일시           57871 non-null  datetime64[ns]
#  10  풍향(deg)      57871 non-null  float64
#  11  풍속(KT)       57871 non-null  float64
#  12  순간풍속(KT)     57871 non-null  float64
#  13  시정(m)        57871 non-null  float64
#  14  일기현상(null)   3485 non-null   float64
#  15  1층 운량(1/8)   51170 non-null  float64
#  16  1층 운형(null)  51170 non-null  float64
#  17  1층 운고(FT)    51170 non-null  float64
# ...

# %%
df_merged = df_merged.drop(labels = '일기현상(null)', axis =1)

# %%
data = df_merged

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57871 entries, 0 to 57870
# Data columns (total 22 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   날짜           57871 non-null  int64
#  1   항공사          57797 non-null  object
#  2   편명           57871 non-null  object
#  3   출발공항코드       57871 non-null  object
#  4   도착공항코드       57871 non-null  object
#  5   계획시간         57871 non-null  object
#  6   예상시간         56727 non-null  object
#  7   출발시간         56808 non-null  object
#  8   현황           57871 non-null  object
#  9   일시           57871 non-null  datetime64[ns]
#  10  풍향(deg)      57871 non-null  float64
#  11  풍속(KT)       57871 non-null  float64
#  12  순간풍속(KT)     57871 non-null  float64
#  13  시정(m)        57871 non-null  float64
#  14  1층 운량(1/8)   51170 non-null  float64
#  15  1층 운형(null)  51170 non-null  float64
#  16  1층 운고(FT)    51170 non-null  float64
#  17  기온(°C)       57871 non-null  float64
# ...

# %%
data = data.drop(labels = ['날짜','계획시간'	,'예상시간'	,'출발시간','일시'],axis = 1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 57871 entries, 0 to 57870
# Data columns (total 17 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   항공사          57797 non-null  object
#  1   편명           57871 non-null  object
#  2   출발공항코드       57871 non-null  object
#  3   도착공항코드       57871 non-null  object
#  4   현황           57871 non-null  object
#  5   풍향(deg)      57871 non-null  float64
#  6   풍속(KT)       57871 non-null  float64
#  7   순간풍속(KT)     57871 non-null  float64
#  8   시정(m)        57871 non-null  float64
#  9   1층 운량(1/8)   51170 non-null  float64
#  10  1층 운형(null)  51170 non-null  float64
#  11  1층 운고(FT)    51170 non-null  float64
#  12  기온(°C)       57871 non-null  float64
#  13  이슬점온도(°C)    57871 non-null  float64
#  14  해면기압(hPa)    57871 non-null  float64
#  15  현지기압(hPa)    57871 non-null  float64
#  16  강수량(mm)      57871 non-null  float64
# dtypes: float64(12), object(5)
# memory usage: 10.0+ MB

# %%
data.describe()
# Out:
#             풍향(deg)        풍속(KT)      순간풍속(KT)         시정(m)    1층 운량(1/8)  \
# count  57871.000000  57871.000000  57871.000000  57871.000000  51170.000000
# mean     181.746874      8.578505      9.039847   7689.077791      3.485301
# std      116.429712      5.402677      6.714031   2347.001884      1.804191
# min        0.000000      0.000000      0.000000     50.000000      1.000000
# 25%       70.000000      4.666667      4.666667   6000.000000      2.000000
# 50%      176.666667      7.166667      7.166667   8000.000000      3.000000
# 75%      300.000000     12.000000     12.000000  10000.000000      4.833333
# max      360.000000     40.000000     59.000000  10000.000000      9.000000
#
#         1층 운형(null)     1층 운고(FT)        기온(°C)     이슬점온도(°C)     해면기압(hPa)  \
# count  51170.000000  51170.000000  57871.000000  57871.000000  57871.000000
# mean       6.030677   3295.309752     16.433875     10.229946   1016.364478
# ...

# %%
data = data.round(3)

# %%
data
# Out:
#           항공사      편명 출발공항코드 도착공항코드  현황  풍향(deg)  풍속(KT)  순간풍속(KT)    시정(m)  \
# 0       이스타항공   ZE230    CJU    GMP  출발   10.000   6.500     6.500  10000.0
# 1       이스타항공   ZE222    CJU    GMP  출발  360.000  11.000    11.000  10000.0
# 2      아시아나항공  OZ8972    CJU    GMP  출발  360.000  11.000    11.000  10000.0
# 3        제주항공   7C804    CJU    CJJ  출발  360.000  11.000    11.000  10000.0
# 4        대한항공  KE1246    CJU    GMP  출발  330.833  10.750    10.750  10000.0
# ...       ...     ...    ...    ...  ..      ...     ...       ...      ...
# 57866  아시아나항공  OZ8124    CJU    TAE  출발  315.000   3.500     3.500  10000.0
# 57867     진에어   LJ308    CJU    GMP  출발  327.500   4.750     4.750  10000.0
# 57868   이스타항공   ZE214    CJU    GMP  출발  330.000   5.000     5.000  10000.0
# 57869    대한항공  KE1222    CJU    GMP  출발  332.500   5.250     5.250  10000.0
# 57870   티웨이항공   TW724    CJU    GMP  출발  250.833   5.417     5.417  10000.0
#
# ...
